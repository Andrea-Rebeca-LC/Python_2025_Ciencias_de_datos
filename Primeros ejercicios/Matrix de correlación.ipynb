# %% [markdown]
# Spearman's Correlation Matrix

# %%
import pandas as pd

CO2Data = pd.read_csv("Terminos_lagoon_TA_DIC_2023_RawData.csv")

# %%
# Selec the columns we want to use
ta_sal_dic_df = CO2Data[['sal_psu', 'ta_micromol_kg', 'dic_micromol_kg']]

# Print df head to check
print(ta_sal_dic_df.head())
# Out:
#    sal_psu  ta_micromol_kg  dic_micromol_kg
# 0     3.56            3863             3915
# 1    16.97            3685             3698
# 2     8.94            3708             3724
# 3    13.87            3992             3667
# 4    28.06            3023             2928

# %%
#Calculate the Spearman correlation matrix
corr_matrix = ta_sal_dic_df.corr(method='spearman')

# %%
# Plot the Spearman correlation matrix

import matplotlib.pyplot as plt
import seaborn as sns

# Plot the heatmap 
plt.figure(figsize=(8, 6))
sns.set(style="white", font_scale=1.2)
sns.heatmap(corr_matrix, 
            annot=True, 
            fmt=".2f", 
            cmap='cividis', 
            square=True, 
            linewidths=0.5, 
            linecolor='gray',
            cbar_kws={'shrink': 0.8})

plt.title('Spearman Correlation Matrix', fontsize=14, weight='bold')
plt.tight_layout()
plt.show()

# %%
temp_sal_chl_df = CO2Data[['temp_c', 'sal_psu', 'chlorophy_microg_l']]

# Print df head to check
print(temp_sal_chl_df.head())
# Out:
#    temp_c  sal_psu  chlorophy_microg_l
# 0  28.740     3.56                0.36
# 1  29.028    16.97                4.19
# 2  29.283     8.94                0.92
# 3  29.024    13.87                2.23
# 4  28.202    28.06                0.58

# %%
corr_matrix = temp_sal_chl_df.corr(method='spearman')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the heatmap 
plt.figure(figsize=(8, 6))
sns.set(style="white", font_scale=1.2)
sns.heatmap(corr_matrix, 
            annot=True, 
            fmt=".2f", 
            cmap='cividis', 
            square=True, 
            linewidths=0.5, 
            linecolor='gray',
            cbar_kws={'shrink': 0.8})

plt.title('Spearman Correlation Matrix', fontsize=14, weight='bold')
plt.tight_layout()
plt.show()
