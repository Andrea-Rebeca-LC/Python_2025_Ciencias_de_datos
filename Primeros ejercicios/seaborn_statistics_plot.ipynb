# %% [markdown]
# Visualización estadistica con Seaborn

# %%
import pandas as pd
# Import the air quality dataset 

CO2Data = pd.read_csv("Terminos_lagoon_TA_DIC_2023_RawData.csv")

print(CO2Data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sample                   106 non-null    object
#  1   date                     106 non-null    object
#  2   estuary                  106 non-null    object
#  3   area                     106 non-null    object
#  4   station                  106 non-null    object
#  5   layer_depth              106 non-null    object
#  6   season                   106 non-null    object
#  7   chlorophy_microg_l       106 non-null    float64
#  8   cond_microsiemens_cm     106 non-null    float64
#  9   depth_m                  106 non-null    float64
#  10  do_percent_sat           106 non-null    float64
#  11  do_mg_l                  106 non-null    float64
#  12  sal_psu                  106 non-null    float64
#  13  sp_cond_microsiemens_cm  106 non-null    float64
# ...

# %% [markdown]
# se crean las librerias y figuras

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

#create your own color array (viridis)
my_colors = ["#5ec962", "#3b528b"]

# add color array to set_palette
sns.set(font_scale=2, style="ticks", palette= my_colors)

# %% [markdown]
# diagrama de caja

# %%
ax = sns.catplot(data=CO2Data,
                 x="area", y="ta_micromol_kg",
                hue="season", col="estuary",
                kind="box", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lab\AppData\Local\Temp\ipykernel_8328\3280352764.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

# %% [markdown]
# violin y catplot

# %%
ax = sns.catplot(data=CO2Data, 
                x="area", y="ta_micromol_kg",
                hue="season", col="estuary", 
                kind="violin", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lab\AppData\Local\Temp\ipykernel_8328\4047047648.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

# %%
ax = sns.catplot(data=CO2Data, 
                x="area", y="ta_micromol_kg",
                hue="season", col="estuary", 
                kind="violin", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# ANOVA

# %%
# grafico de puntos anova de 3 vías
ax = sns.catplot(
    data=CO2Data, x="season", 
    y="ta_micromol_kg", hue="estuary", col="area",
    capsize=.2, palette="YlGnBu_d", errorbar="se",
    kind="point", height=6, aspect=.75,
)
ax.despine(left=True)

ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lab\AppData\Local\Temp\ipykernel_8328\2613193092.py:10: SyntaxWarning: invalid escape sequence '\m'
#   ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

# %% [markdown]
# diagramas de dispesión

# %%
ax = sns.lmplot(x="sal_psu", y="ta_micromol_kg",
                hue="season",col="estuary",
                data=CO2Data, 
                height=7, aspect=1)

ax.set(xlabel='Salinity (PSU)', ylabel=' DIC ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lab\AppData\Local\Temp\ipykernel_8328\3035663267.py:6: SyntaxWarning: invalid escape sequence '\m'
#   ax.set(xlabel='Salinity (PSU)', ylabel=' DIC ($\mu mol \; kg^{-1}$)')

# %% [markdown]
# mi base de datos

# %%
import pandas as pd
# Import the air quality dataset 

CHL = pd.read_csv("insitu y satelital.csv")

print(CHL.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             187 non-null    object
#  1   station          187 non-null    int64
#  2   sd.oc3           163 non-null    float64
#  3   oc3              163 non-null    float64
#  4   sd.ocx           156 non-null    float64
#  5   ocx              156 non-null    float64
#  6   sd.mdn           157 non-null    float64
#  7   mdn              157 non-null    float64
#  8   chlorophyll.ugl  187 non-null    float64
#  9   chlorophyll.u    131 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 14.7+ KB
# None

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

#paleta de colores
my_colors_E = ["#74add1", "#4575b4", "#313695","#006837","#a6d96a",  "#fdae61","#f46d43","#d73027","#a50026", "#67000d"]

# add color array to set_palette
sns.set(font_scale=2, style="ticks", palette= my_colors_E)

# %% [markdown]
# Grafico de dispersión

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

ax = sns.scatterplot(
    data=CHL,
    x="chlorophyll.ugl",
    y="mdn",
    hue="station",
    palette=my_colors_E,
    legend="full"
)

# Personalizar leyenda
plt.legend(
    bbox_to_anchor=(1.05, 1),   # a mueve fuera a la derecha
    loc='upper left',           #  anclada arriba a la izquierda del cuadro
    borderaxespad=0,
    title="Estación",
    prop={'size': 8}            #  tamaño de texto 
)

plt.xlabel(r"EXO Chl-$\it{a}$  ($\mu g \, L^{-1}$)", fontsize=12)
plt.ylabel(r"Sentinel-2 MDN Chl-$\it{a}$  ($\mu g \, L^{-1}$)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# Bloxplot por estación

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# organizar datos 
df_long = CHL.melt(
    id_vars="station",                          # columna que se mantiene
    value_vars=["oc3", "ocx", "mdn", "chlorophyll.ugl"],  # columnas a comparar
    var_name="Variable", 
    value_name="Concentración"
)

plt.figure(figsize=(12,6))

sns.boxplot(
    data=df_long,
    x="station",         # estaciones en eje X
    y="Concentración",   # valores en eje Y
    hue="Variable",      # cada variable con distinto color
    palette="Set2"       # cambiar los colores
)

plt.xlabel("Estación", fontsize=12)
plt.ylabel("Concentración de Clorofila (µg/L)", fontsize=12)
plt.title("Comparación de métodos de clorofila por estación", fontsize=14)

plt.legend(title="Método", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Renombrar variables
df_long_renamed = df_long.copy()

# Nuevos nombres
rename_dict = {
    "oc3": "OC3 (Sentinel-2)",
    "ocx": "OCx (Sentinel-2)",
    "mdn": "MDN (Sentinel-2)",
    "chlorophyll.ugl": "EXO Chl-a (in situ)"
}

# Reemplazar los nombres
df_long_renamed["Variable"] = df_long_renamed["Variable"].map(rename_dict)

# Boxplot
plt.figure(figsize=(12,6))

sns.boxplot(
    data=df_long_renamed,
    x="station",
    y="Concentración",
    hue="Variable",
    palette=my_colors_E  # tu paleta personalizada
)

plt.xlabel("Estación", fontsize=12)
plt.ylabel("Concentración de Clorofila (µg/L)", fontsize=12)
plt.title("Comparación de métodos de clorofila por estación", fontsize=14)

plt.legend(title="Método", bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size':10})
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lab\AppData\Local\Temp\ipykernel_19344\2393505963.py:18: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.boxplot(
